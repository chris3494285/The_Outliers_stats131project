# %%
import pandas as pd
crime = pd.read_csv("/Users/Jennifer/Desktop/crime-in-los-angeles/Crime_Data_2010_2017.csv")

# %%
columns = ['DR Number', 'Area ID','Crime Code','MO Codes', 'Premise Code','Weapon Used Code','Status Code','Address','Cross Street']
crime.drop(columns, inplace=True, axis=1)
crime.rename(columns={'Date Reported': 'DateReported', 'Date Occurred': 'DateOccurred','Time Occurred':'TimeOccured',
                      'Area Name':'AreaName','Reporting District':'ReportingDistrict','Crime Code Description':'CrimeCodeDescription',
                      'Victim Age':'VictimAge','Victim Sex':'VictimSex','Victim Descent':'VictimDescent','Premise Description':'PremiseDescription',
                     'Status Description':'StatusDescription', 'Crime Code 1':'CrimeCode1','Crime Code 2':'CrimeCode2', 'Crime Code 3':'CrimeCode3',
                     'Crime Code 4':'CrimeCode4'}, inplace=True)
df = crime.loc[crime.CrimeCodeDescription=='ROBBERY', :]
df.head()
# Out:
#    DateReported DateOccurred  TimeOccured AreaName  ReportingDistrict  \
# 28   01/12/2013   01/12/2013         1815  Central                105
# 39   01/20/2013   01/20/2013         1430  Central                135
# 49   01/25/2013   01/25/2013         2305  Central                185
# 50   01/28/2013   01/27/2013         1835  Central                176
# 51   01/29/2013   01/28/2013          845  Central                152
#
#    CrimeCodeDescription  VictimAge VictimSex VictimDescent PremiseDescription  \
# 28              ROBBERY       24.0         M             H             STREET
# 39              ROBBERY        NaN         F             H      JEWELRY STORE
# 49              ROBBERY       57.0         M             H        PARKING LOT
# 50              ROBBERY       56.0         F             O     OTHER BUSINESS
# 51              ROBBERY       26.0         M             H        OTHER STORE
#
#                                 Weapon Description StatusDescription  \
# 28  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)       Invest Cont
# 39  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)       Invest Cont
# 49  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)      Adult Arrest
# 50  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)      Adult Arrest
# 51  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)      Adult Arrest
#
#     CrimeCode1  CrimeCode2  CrimeCode3  CrimeCode4             Location
# 28       210.0         NaN         NaN         NaN  (34.0688, -118.2333)
# 39       210.0       998.0         NaN         NaN  (34.0503, -118.2433)
# 49       210.0       998.0         NaN         NaN  (34.0405, -118.2567)
# 50       210.0         NaN         NaN         NaN   (34.0383, -118.254)
# 51       210.0         NaN         NaN         NaN  (34.0481, -118.2542)

# %%
#### count of missing data
len(df.index)-df.count()
# Out:
# DateReported                0
# DateOccurred                0
# TimeOccured                 0
# AreaName                    0
# ReportingDistrict           0
# CrimeCodeDescription        0
# VictimAge                4747
# VictimSex                  50
# VictimDescent              51
# PremiseDescription         93
# Weapon Description        207
# StatusDescription           0
# CrimeCode1                  1
# CrimeCode2              56116
# CrimeCode3              63192
# CrimeCode4              63398
# Location                    1
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
Weapon = df["AreaName"]
plt.figure(figsize=(15, 15))
sns.countplot(y = Weapon, hue = df["VictimSex"],order = Weapon.value_counts(normalize = True).head(25).index)

# %%
Prem = df["PremiseDescription"]
plt.figure(figsize=(15, 30))
sns.countplot(y = Prem,hue = df["VictimDescent"],order = Prem.value_counts(normalize = True).head(10).index)
plt.legend(loc=(1.04,0))

# %%
weapon = df["Weapon Description"]
plt.figure(figsize=(10, 10))
sns.countplot(y = weapon,hue = df["VictimSex"],order = weapon.value_counts(normalize = True).head(10).index)
plt.legend(loc=(1.04,0))
